# %%
# !pip install pysentimiento
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.2/251.2 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 6.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 7.2 MB/s eta 0:00:00
# ...
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171033 sha256=18f6d775c987846d8c74d6e710659815737f0bbb1529f39ebceae90715d9dd6c
#   Stored in directory: /root/.cache/pip/wheels/31/8a/8c/315c9e5d7773f74b33d5ed33f075b49c6eaeb7cedbb86e2cf8
# Successfully built emoji
# ...

# %% [markdown]
# # LOAD PACKAGES

# %%
from pysentimiento import create_analyzer

# %% [markdown]
# # EMOTION DETECTION AND CHECKING

# %%
emotion = create_analyzer(task='emotion',lang='en')
result = emotion.predict('get out of my way')
result.output
# Out:
# 'anger'

# %% [markdown]
# # CREATING A FUNCTION FOR DETECTING THE EMOTION

# %%
def emotion_detection(text):
  emotion = create_analyzer(task='emotion',lang='en')
  result = emotion.predict(text)
  return result.output

emotion_detection("i love data science")
# Out:
# 'joy'

# %% [markdown]
# # HATESPEECH DETECTION

# %%
hatespeech = create_analyzer(task='hate_speech',lang='en')
# Out:
# config.json:   0%|          | 0.00/980 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/540M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/338 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/843k [00:00<?, ?B/s]
# bpe.codes:   0%|          | 0.00/1.08M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/22.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/167 [00:00<?, ?B/s]
# []

# %%
hatespeech = create_analyzer(task='hate_speech',lang='en')
result = hatespeech.predict("i hate data science")
next(iter(result.probas.items()),None)
# Out:
# ('hateful', 0.02702677622437477)

# %% [markdown]
# # CREATING FUNCTION FOR HATESPEECH DETECTION

# %%
def hatespeech_detection(text):
  hatespeech = create_analyzer(task='hate_speech', lang='en')
  result = hatespeech.predict(text)
  return next(iter(result.probas.items()),None)
hatespeech_detection("I hate eating apples. that's why i don't want to sit with appple seller")
# Out:
# ('hateful', 0.030125703662633896)

# %% [markdown]
# # PREDICTIVE SYSTEM

# %%
text = """I woke up this morning feeling incredibly happy and grateful for the beautiful weather outside.
 The sun was shining, birds were singing, and there was a gentle breeze in the air. It felt like the
 perfect day to go for a long walk in the park."""

# %%
emo = emotion_detection(text)
hate = hatespeech_detection(text)

print("Emotion :", emo)
print("Speech :", hate)
# Out:
# Emotion : joy
# Speech : ('hateful', 0.015868615359067917)

# %% [markdown]
# # TESTING THE SYSTEM AGAIN

# %%
text2 = """In the evening, I decided to unwind by watching a comedy show. The hilarious jokes and witty banter lifted my spirits, and I found myself laughing uncontrollably.
 Laughter truly is the best medicine, and it was the perfect way to end the day on a positive note.
"""

# %%
emo = emotion_detection(text2)
hate = hatespeech_detection(text2)

print("Emotion :", emo)
print("Speech :", hate)
# Out:
# Emotion : joy
# Speech : ('hateful', 0.014117322862148285)
